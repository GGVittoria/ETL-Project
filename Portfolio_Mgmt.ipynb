# %% [markdown]
# # ETL Project - Portfolio Management Data
#
# The customer currently manages their portfolio of projects using Excel spreadsheets and it is difficult for them to know if or how each project is tied to the company’s strategies. The customer has provided two separate Excel spreadsheets and I saved them as CSV files: (1) project listing with project details and (2) project strategy and risk information.
#
# Please be aware that this is not proprietary data. The customer provided sample data and they had modified anything that was proprietary before turning over the Excel files.

# %%
# Dependencies and Setup
import pandas as pd
from sqlalchemy import create_engine
from config import db_connection

# Read the CSV files
projects = "Data/projects.csv"
strategy = "Data/strategy.csv"

# %%
# Create the data frame - projects
projects_df = pd.read_csv(projects, delimiter=',', skipinitialspace=True)

# Display the projects data for preview
projects_df
# Out:
#        Project ID                           Project Name Start Date  \
# 0    AB-U38510550  Upgrd - Facilities Maintenance System   6/7/2019
# 1    AC-D39121594                DB2 to Oracle Migration   2/8/2018
# 2    AC-G38719560                   General Ledger (ERP)   1/2/2020
# 3    AC-M39177596             Marketing Data Integration   4/5/2018
# 4    AC-M39177596             Marketing Data Integration   4/5/2018
# ..            ...                                    ...        ...
# 630  WS-S40909321              Single Sign On and Portal   1/1/2020
# 631  WS-S40909791                  Sales Training Design   1/1/2020
# 632  WS-T39914244                        Treasury Portal  4/11/2020
# 633  WS-W40909395           Workflow Enablement - Wave 3   1/1/2020
# 634  WS-W40909396           Workflow Enablement - Wave 2   1/1/2020
#
#        End Date   Days                                        Description  \
# 0      5/1/2020  329.0  Managing assets is a critical component to the...
# 1    11/10/2018  275.0                                                NaN
# 2     4/20/2020  109.0  The General Ledger (ERP) project supports the ...
# 3     2/23/2019  324.0                                                NaN
# 4     2/23/2019  324.0                                                NaN
# ..          ...    ...                                                ...
# 630  12/31/2020  365.0  This project is intended to provide a single s...
# 631    1/1/2020    0.0  Implement RM on-boarding and training program ...
# 632  11/15/2020  218.0  Treasury clients today use a variety of produc...
# 633    1/1/2020    0.0           Extend workflow capabilities to all LOBs
# 634    1/1/2020    0.0  Enhance workflow to accommodate deal routing b...
#
#     Number of Dependents Total Funded Budget Total Planned Cost  \
# 0                      4              75,497            163,000
# 1                    NaN             310,000            310,000
# 2                      ?                   0            550,000
# 3                    NaN             150,000            150,000
# 4                    NaN             150,000            150,000
# ..                   ...                 ...                ...
# 630                    2                 NaN            115,500
# 631                    ?                 NaN            142,300
# 632                    4                   0            156,000
# 633                    3                 NaN            101,000
# 634                    2                 NaN            155,700
#
#     Portfolio Executive                     Segment     Life Cycle  \
# 0          Greiff, Gene                   Annuities        Operate
# 1      Kellerman, Henry            Asset Management  Business Case
# 2       Mitchell, Linda            Asset Management       Delivery
# 3          Bing, Jeremy  Advice & Wealth Management        Concept
# 4          Bing, Jeremy  Advice & Wealth Management        Concept
# ..                  ...                         ...            ...
# 630       Waterman, Lee                   Wholesale     Initiation
# 631         Rink, Jenna                   Wholesale     Initiation
# 632                 NaN                   Wholesale      Execution
# 633      Street, Stella                   Wholesale     Initiation
# 634       Phillips, Doc                   Wholesale     Initiation
#
#                    Project Type     Status Funding Status  \
# 0                  Breakthrough       Open       Finished
# 1                          Core       Open         Funded
# 2                          Core       Open       Proposed
# 3                          Core       Open         Funded
# 4                          Core       Open         Funded
# ..                          ...        ...            ...
# 630          Strategic Priority  Candidate         Demand
# 631               Discretionary  Candidate         Demand
# 632                Breakthrough       Open       Canceled
# 633  Improvement/Line Extension  Candidate         Demand
# 634                Breakthrough  Candidate         Demand
#
#                                         Type Total Actual Cost
# 0                     Six Sigma Kaizen event            75,497
# 1    IT Waterfall traditional implementation                 0
# 2    IT Waterfall traditional implementation                 0
# 3                     Six Sigma Kaizen event                 0
# 4                     Six Sigma Kaizen event                 0
# ..                                       ...               ...
# 630                   Six Sigma Kaizen event               NaN
# 631                   Six Sigma Kaizen event               NaN
# 632  IT Waterfall traditional implementation                 0
# 633                   Six Sigma Kaizen event                 0
# 634                   Six Sigma Kaizen event               NaN
#
# [635 rows x 17 columns]

# %%
# Create the data frame - strategy
strategy_df = pd.read_csv(strategy, delimiter=',', skipinitialspace=True)

# Display the strategy data for preview
strategy_df
# Out:
#        Project ID  Strategy Score  Risk Score  \
# 0    AB-U38510550              59        73.0
# 1    AC-D39121594              36        33.0
# 2    AC-G38719560              36        77.0
# 3    AC-M39177596              50        40.0
# 4    AC-R38763567              89        70.0
# ..            ...             ...         ...
# 609  WS-S40909321              75        43.0
# 610  WS-S40909791              52        43.0
# 611  WS-T39914244              66        70.0
# 612  WS-W40909395              37        57.0
# 613  WS-W40909396              57        30.0
#
#     Risk - # of Vendors Contributing Risk - Business Problem Clearly Defined  \
# 0                               High                                     Med
# 1                                Low                                     Low
# 2                                Med                                     Low
# 3                                Low                                     Low
# 4                                Med                                    High
# ..                               ...                                     ...
# 609                              Low                                     Low
# 610                              Low                                     Low
# 611                              Med                                    High
# 612                              Low                                     Med
# 613                                -                                    High
#
#     Risk - Business Processes Impacted  \
# 0                                  Med
# 1                                  Low
# 2                                  Med
# 3                                  Low
# 4                                  Med
# ..                                 ...
# 609                                Med
# 610                                Med
# 611                                Med
# 612                               High
# 613                                  -
#
#     Risk - Impact to Key Financial Application  \
# 0                                          Low
# 1                                          Low
# 2                                         High
# 3                                          Low
# 4                                         High
# ..                                         ...
# 609                                        Med
# 610                                        Med
# 611                                       High
# 612                                        Med
# 613                                          -
#
#     Risk - Level of User Change Management Risk - Market  \
# 0                                     High           Med
# 1                                      Low           Low
# 2                                      Med          High
# 3                                      Low           Med
# 4                                      Med           Low
# ..                                     ...           ...
# 609                                    Low           Low
# 610                                    Low           Low
# 611                                    Med           Low
# 612                                    Low           Med
# 613                                      -          High
#
#     Risk - New Product, Functionality or Service  ...  \
# 0                                            Low  ...
# 1                                            Low  ...
# 2                                           High  ...
# 3                                            Low  ...
# 4                                           High  ...
# ..                                           ...  ...
# 609                                          Med  ...
# 610                                          Med  ...
# 611                                         High  ...
# 612                                          Med  ...
# 613                                            -  ...
#
#     Support for Competitive Differentiation Mandatory? Business Priority  \
# 0                               Very Strong         No               NaN
# 1                                  Moderate        NaN               NaN
# 2                                      Weak         No               NaN
# 3                                    Strong        NaN               NaN
# 4                               Very Strong        NaN               NaN
# ..                                      ...        ...               ...
# 609                                Moderate         No               NaN
# 610                                Moderate         No               NaN
# 611                             Very Strong        NaN               NaN
# 612                                    Weak        Yes               NaN
# 613                                    Weak         No               NaN
#
#     Forced Rank Risk Eval Risk - Acceptance Risk - Skills / Capability  \
# 0           NaN      67.0               Med                        Med
# 1           NaN      33.0               Low                        Low
# 2           NaN      83.0              High                        Med
# 3           NaN      50.0               Med                        Low
# 4           NaN      50.0               Low                        Med
# ..          ...       ...               ...                        ...
# 609         NaN      50.0               Low                        Med
# 610         NaN      50.0               Low                        Med
# 611         NaN      50.0               Low                        Med
# 612         NaN      83.0               Med                       High
# 613         NaN      50.0              High                          -
#
#     Risk - Complexity Risk - Product / Technology Risk - Planning
# 0                High                         Low             Med
# 1                 Low                         Low             Low
# 2                 Med                        High             Low
# 3                 Low                         Low             Low
# 4                 Med                        High            High
# ..                ...                         ...             ...
# 609               Low                         Med             Low
# 610               Low                         Med             Low
# 611               Med                        High            High
# 612               Low                         Med             Med
# 613                 -                           -            High
#
# [614 rows x 29 columns]

# %% [markdown]
# ## Transform the data
#
# * Remove duplicates, select columns, clean data, join the two datasets

# %%
# Check the number of unique records in projects using groupby
projects_group = projects_df.groupby(["Project ID"])
len(projects_group)
# Out:
# 629

# %%
# Get all the data for the duplicate rows in projects
duplicateRow = projects_df[projects_df.duplicated()]
duplicateRow
# Out:
#        Project ID                 Project Name Start Date    End Date   Days  \
# 4    AC-M39177596   Marketing Data Integration   4/5/2018   2/23/2019  324.0
# 6    AC-R38763567          Requirements System  2/15/2020   3/23/2020   37.0
# 426  TM-L39909243         Legacy MDS Migration   4/6/2020   6/15/2020   70.0
# 495  WM-D40909401    Deliver ESP Card Releases   1/1/2020  12/31/2020  365.0
# 526   WM-T4090977  TPS EIS Planning Allocation   1/1/2020  12/31/2020  365.0
#
#                                            Description Number of Dependents  \
# 4                                                  NaN                  NaN
# 6                                                  NaN                  NaN
# 426  Update the middleware Message Broker flows fro...                    ?
# 495  Focused on enhancing the competitiveness of th...                    5
# 526                        TPS EIS Planning Allocation                    0
#
#     Total Funded Budget Total Planned Cost Portfolio Executive  \
# 4               150,000            150,000        Bing, Jeremy
# 6               186,000            186,000    Vincent, Jeanine
# 426             159,000            155,250                 NaN
# 495                 NaN             83,781     Hammond, Carrie
# 526                 NaN             65,152                 NaN
#
#                         Segment   Life Cycle       Project Type     Status  \
# 4    Advice & Wealth Management      Concept               Core       Open
# 6                     Annuities      Concept               Core       Open
# 426   Technology and Operations  Realization  Maintenance-Other       Open
# 495                   Wholesale   Initiation  Maintenance-Other  Candidate
# 526                   Wholesale   Initiation      Discretionary  Candidate
#
#     Funding Status                                     Type Total Actual Cost
# 4           Funded                   Six Sigma Kaizen event                 0
# 6           Funded  IT Waterfall traditional implementation                 0
# 426      Completed                   Six Sigma Kaizen event               NaN
# 495       Canceled  IT Waterfall traditional implementation                 0
# 526       Canceled  IT Waterfall traditional implementation                 0

# %%
# List the index for each duplicated rows in projects
list_index = projects_df[projects_df.duplicated()].index.tolist()
list_index
# Out:
# [4, 6, 426, 495, 526]

# %%
# Create a clean projects data frame by dropping the duplicate rows by its index
projects_df = projects_df.drop(list_index)
projects_df
# Out:
#        Project ID                           Project Name Start Date  \
# 0    AB-U38510550  Upgrd - Facilities Maintenance System   6/7/2019
# 1    AC-D39121594                DB2 to Oracle Migration   2/8/2018
# 2    AC-G38719560                   General Ledger (ERP)   1/2/2020
# 3    AC-M39177596             Marketing Data Integration   4/5/2018
# 5    AC-R38763567                    Requirements System  2/15/2020
# ..            ...                                    ...        ...
# 630  WS-S40909321              Single Sign On and Portal   1/1/2020
# 631  WS-S40909791                  Sales Training Design   1/1/2020
# 632  WS-T39914244                        Treasury Portal  4/11/2020
# 633  WS-W40909395           Workflow Enablement - Wave 3   1/1/2020
# 634  WS-W40909396           Workflow Enablement - Wave 2   1/1/2020
#
#        End Date   Days                                        Description  \
# 0      5/1/2020  329.0  Managing assets is a critical component to the...
# 1    11/10/2018  275.0                                                NaN
# 2     4/20/2020  109.0  The General Ledger (ERP) project supports the ...
# 3     2/23/2019  324.0                                                NaN
# 5     3/23/2020   37.0                                                NaN
# ..          ...    ...                                                ...
# 630  12/31/2020  365.0  This project is intended to provide a single s...
# 631    1/1/2020    0.0  Implement RM on-boarding and training program ...
# 632  11/15/2020  218.0  Treasury clients today use a variety of produc...
# 633    1/1/2020    0.0           Extend workflow capabilities to all LOBs
# 634    1/1/2020    0.0  Enhance workflow to accommodate deal routing b...
#
#     Number of Dependents Total Funded Budget Total Planned Cost  \
# 0                      4              75,497            163,000
# 1                    NaN             310,000            310,000
# 2                      ?                   0            550,000
# 3                    NaN             150,000            150,000
# 5                    NaN             186,000            186,000
# ..                   ...                 ...                ...
# 630                    2                 NaN            115,500
# 631                    ?                 NaN            142,300
# 632                    4                   0            156,000
# 633                    3                 NaN            101,000
# 634                    2                 NaN            155,700
#
#     Portfolio Executive                     Segment     Life Cycle  \
# 0          Greiff, Gene                   Annuities        Operate
# 1      Kellerman, Henry            Asset Management  Business Case
# 2       Mitchell, Linda            Asset Management       Delivery
# 3          Bing, Jeremy  Advice & Wealth Management        Concept
# 5      Vincent, Jeanine                   Annuities        Concept
# ..                  ...                         ...            ...
# 630       Waterman, Lee                   Wholesale     Initiation
# 631         Rink, Jenna                   Wholesale     Initiation
# 632                 NaN                   Wholesale      Execution
# 633      Street, Stella                   Wholesale     Initiation
# 634       Phillips, Doc                   Wholesale     Initiation
#
#                    Project Type     Status Funding Status  \
# 0                  Breakthrough       Open       Finished
# 1                          Core       Open         Funded
# 2                          Core       Open       Proposed
# 3                          Core       Open         Funded
# 5                          Core       Open         Funded
# ..                          ...        ...            ...
# 630          Strategic Priority  Candidate         Demand
# 631               Discretionary  Candidate         Demand
# 632                Breakthrough       Open       Canceled
# 633  Improvement/Line Extension  Candidate         Demand
# 634                Breakthrough  Candidate         Demand
#
#                                         Type Total Actual Cost
# 0                     Six Sigma Kaizen event            75,497
# 1    IT Waterfall traditional implementation                 0
# 2    IT Waterfall traditional implementation                 0
# 3                     Six Sigma Kaizen event                 0
# 5    IT Waterfall traditional implementation                 0
# ..                                       ...               ...
# 630                   Six Sigma Kaizen event               NaN
# 631                   Six Sigma Kaizen event               NaN
# 632  IT Waterfall traditional implementation                 0
# 633                   Six Sigma Kaizen event                 0
# 634                   Six Sigma Kaizen event               NaN
#
# [630 rows x 17 columns]

# %%
# Select the project columns needed for portfolio analysis
projects_df = projects_df[["Project ID", "Project Name","Start Date", "End Date", "Description",
                           "Number of Dependents", "Total Funded Budget", "Total Planned Cost", 
                           "Portfolio Executive", "Segment", "Project Type", "Status", "Funding Status", 
                           "Total Actual Cost"]]
                     
# Display the new dataframe
projects_df.head()
# Out:
#      Project ID                           Project Name Start Date    End Date  \
# 0  AB-U38510550  Upgrd - Facilities Maintenance System   6/7/2019    5/1/2020
# 1  AC-D39121594                DB2 to Oracle Migration   2/8/2018  11/10/2018
# 2  AC-G38719560                   General Ledger (ERP)   1/2/2020   4/20/2020
# 3  AC-M39177596             Marketing Data Integration   4/5/2018   2/23/2019
# 5  AC-R38763567                    Requirements System  2/15/2020   3/23/2020
#
#                                          Description Number of Dependents  \
# 0  Managing assets is a critical component to the...                    4
# 1                                                NaN                  NaN
# 2  The General Ledger (ERP) project supports the ...                    ?
# 3                                                NaN                  NaN
# 5                                                NaN                  NaN
#
#   Total Funded Budget Total Planned Cost Portfolio Executive  \
# 0              75,497            163,000        Greiff, Gene
# 1             310,000            310,000    Kellerman, Henry
# 2                   0            550,000     Mitchell, Linda
# 3             150,000            150,000        Bing, Jeremy
# 5             186,000            186,000    Vincent, Jeanine
#
#                       Segment  Project Type Status Funding Status  \
# 0                   Annuities  Breakthrough   Open       Finished
# 1            Asset Management          Core   Open         Funded
# 2            Asset Management          Core   Open       Proposed
# 3  Advice & Wealth Management          Core   Open         Funded
# 5                   Annuities          Core   Open         Funded
#
#   Total Actual Cost
# 0            75,497
# 1                 0
# 2                 0
# 3                 0
# 5                 0

# %%
# Check the number of unique records in strategy using groupby
strategy_group = strategy_df.groupby(["Project ID"])
len(strategy_group)
# Out:
# 612

# %%
# Get all the data for the duplicate rows in strategy
duplicateRow = strategy_df[strategy_df.duplicated()]
duplicateRow
# Out:
#        Project ID  Strategy Score  Risk Score  \
# 412  TM-F40287631              76        50.0
# 506  WM-R40940455              73        33.0
#
#     Risk - # of Vendors Contributing Risk - Business Problem Clearly Defined  \
# 412                              Low                                     Med
# 506                              Low                                     Low
#
#     Risk - Business Processes Impacted  \
# 412                               High
# 506                                Low
#
#     Risk - Impact to Key Financial Application  \
# 412                                        Med
# 506                                        Low
#
#     Risk - Level of User Change Management Risk - Market  \
# 412                                    Low           Low
# 506                                    Low           Low
#
#     Risk - New Product, Functionality or Service  ...  \
# 412                                          Med  ...
# 506                                          Low  ...
#
#     Support for Competitive Differentiation Mandatory? Business Priority  \
# 412                                    Weak         No               NaN
# 506                               Mandatory        Yes               NaN
#
#     Forced Rank Risk Eval Risk - Acceptance Risk - Skills / Capability  \
# 412         NaN      67.0               Low                       High
# 506         NaN      33.0               Low                        Low
#
#     Risk - Complexity Risk - Product / Technology Risk - Planning
# 412               Low                         Med             Med
# 506               Low                         Low             Low
#
# [2 rows x 29 columns]

# %%
# List the index for each duplicated rows in strategy
list_index = strategy_df[strategy_df.duplicated()].index.tolist()
list_index
# Out:
# [412, 506]

# %%
# Create a clean strategy data frame by dropping the duplicate rows by its index
strategy_df = strategy_df.drop(list_index)
strategy_df
# Out:
#        Project ID  Strategy Score  Risk Score  \
# 0    AB-U38510550              59        73.0
# 1    AC-D39121594              36        33.0
# 2    AC-G38719560              36        77.0
# 3    AC-M39177596              50        40.0
# 4    AC-R38763567              89        70.0
# ..            ...             ...         ...
# 609  WS-S40909321              75        43.0
# 610  WS-S40909791              52        43.0
# 611  WS-T39914244              66        70.0
# 612  WS-W40909395              37        57.0
# 613  WS-W40909396              57        30.0
#
#     Risk - # of Vendors Contributing Risk - Business Problem Clearly Defined  \
# 0                               High                                     Med
# 1                                Low                                     Low
# 2                                Med                                     Low
# 3                                Low                                     Low
# 4                                Med                                    High
# ..                               ...                                     ...
# 609                              Low                                     Low
# 610                              Low                                     Low
# 611                              Med                                    High
# 612                              Low                                     Med
# 613                                -                                    High
#
#     Risk - Business Processes Impacted  \
# 0                                  Med
# 1                                  Low
# 2                                  Med
# 3                                  Low
# 4                                  Med
# ..                                 ...
# 609                                Med
# 610                                Med
# 611                                Med
# 612                               High
# 613                                  -
#
#     Risk - Impact to Key Financial Application  \
# 0                                          Low
# 1                                          Low
# 2                                         High
# 3                                          Low
# 4                                         High
# ..                                         ...
# 609                                        Med
# 610                                        Med
# 611                                       High
# 612                                        Med
# 613                                          -
#
#     Risk - Level of User Change Management Risk - Market  \
# 0                                     High           Med
# 1                                      Low           Low
# 2                                      Med          High
# 3                                      Low           Med
# 4                                      Med           Low
# ..                                     ...           ...
# 609                                    Low           Low
# 610                                    Low           Low
# 611                                    Med           Low
# 612                                    Low           Med
# 613                                      -          High
#
#     Risk - New Product, Functionality or Service  ...  \
# 0                                            Low  ...
# 1                                            Low  ...
# 2                                           High  ...
# 3                                            Low  ...
# 4                                           High  ...
# ..                                           ...  ...
# 609                                          Med  ...
# 610                                          Med  ...
# 611                                         High  ...
# 612                                          Med  ...
# 613                                            -  ...
#
#     Support for Competitive Differentiation Mandatory? Business Priority  \
# 0                               Very Strong         No               NaN
# 1                                  Moderate        NaN               NaN
# 2                                      Weak         No               NaN
# 3                                    Strong        NaN               NaN
# 4                               Very Strong        NaN               NaN
# ..                                      ...        ...               ...
# 609                                Moderate         No               NaN
# 610                                Moderate         No               NaN
# 611                             Very Strong        NaN               NaN
# 612                                    Weak        Yes               NaN
# 613                                    Weak         No               NaN
#
#     Forced Rank Risk Eval Risk - Acceptance Risk - Skills / Capability  \
# 0           NaN      67.0               Med                        Med
# 1           NaN      33.0               Low                        Low
# 2           NaN      83.0              High                        Med
# 3           NaN      50.0               Med                        Low
# 4           NaN      50.0               Low                        Med
# ..          ...       ...               ...                        ...
# 609         NaN      50.0               Low                        Med
# 610         NaN      50.0               Low                        Med
# 611         NaN      50.0               Low                        Med
# 612         NaN      83.0               Med                       High
# 613         NaN      50.0              High                          -
#
#     Risk - Complexity Risk - Product / Technology Risk - Planning
# 0                High                         Low             Med
# 1                 Low                         Low             Low
# 2                 Med                        High             Low
# 3                 Low                         Low             Low
# 4                 Med                        High            High
# ..                ...                         ...             ...
# 609               Low                         Med             Low
# 610               Low                         Med             Low
# 611               Med                        High            High
# 612               Low                         Med             Med
# 613                 -                           -            High
#
# [612 rows x 29 columns]

# %%
# Select the strategy and risk columns needed for the analysis
strategy_df = strategy_df[["Project ID", "Strategy Score","Primary Support Strategy", "Risk Score"]]
                     
# dDisplay the new data frame
strategy_df
# Out:
#        Project ID  Strategy Score                 Primary Support Strategy  \
# 0    AB-U38510550              59  Support for Competitive Differentiation
# 1    AC-D39121594              36           Support for External Customers
# 2    AC-G38719560              36       Support for Increased Productivity
# 3    AC-M39177596              50           Support for External Customers
# 4    AC-R38763567              89           Support for External Customers
# ..            ...             ...                                      ...
# 609  WS-S40909321              75       Support for Increased Productivity
# 610  WS-S40909791              52       Support for Increased Productivity
# 611  WS-T39914244              66           Support for External Customers
# 612  WS-W40909395              37               Support for Reducing Costs
# 613  WS-W40909396              57               Support for Reducing Costs
#
#      Risk Score
# 0          73.0
# 1          33.0
# 2          77.0
# 3          40.0
# 4          70.0
# ..          ...
# 609        43.0
# 610        43.0
# 611        70.0
# 612        57.0
# 613        30.0
#
# [612 rows x 4 columns]

# %% [markdown]
# ### Replacing missing values in projects with 0
#
# * Some of the variables have a value of "?" and need to be replaced with a zero

# %%
# Replacing missing data with a zero
projects_df = projects_df.replace(to_replace ="?", 
                                 value =0)

# %%
# Preview clean dataset
projects_df
# Out:
#        Project ID                           Project Name Start Date  \
# 0    AB-U38510550  Upgrd - Facilities Maintenance System   6/7/2019
# 1    AC-D39121594                DB2 to Oracle Migration   2/8/2018
# 2    AC-G38719560                   General Ledger (ERP)   1/2/2020
# 3    AC-M39177596             Marketing Data Integration   4/5/2018
# 5    AC-R38763567                    Requirements System  2/15/2020
# ..            ...                                    ...        ...
# 630  WS-S40909321              Single Sign On and Portal   1/1/2020
# 631  WS-S40909791                  Sales Training Design   1/1/2020
# 632  WS-T39914244                        Treasury Portal  4/11/2020
# 633  WS-W40909395           Workflow Enablement - Wave 3   1/1/2020
# 634  WS-W40909396           Workflow Enablement - Wave 2   1/1/2020
#
#        End Date                                        Description  \
# 0      5/1/2020  Managing assets is a critical component to the...
# 1    11/10/2018                                                NaN
# 2     4/20/2020  The General Ledger (ERP) project supports the ...
# 3     2/23/2019                                                NaN
# 5     3/23/2020                                                NaN
# ..          ...                                                ...
# 630  12/31/2020  This project is intended to provide a single s...
# 631    1/1/2020  Implement RM on-boarding and training program ...
# 632  11/15/2020  Treasury clients today use a variety of produc...
# 633    1/1/2020           Extend workflow capabilities to all LOBs
# 634    1/1/2020  Enhance workflow to accommodate deal routing b...
#
#     Number of Dependents Total Funded Budget Total Planned Cost  \
# 0                      4              75,497            163,000
# 1                    NaN             310,000            310,000
# 2                      0                   0            550,000
# 3                    NaN             150,000            150,000
# 5                    NaN             186,000            186,000
# ..                   ...                 ...                ...
# 630                    2                 NaN            115,500
# 631                    0                 NaN            142,300
# 632                    4                   0            156,000
# 633                    3                 NaN            101,000
# 634                    2                 NaN            155,700
#
#     Portfolio Executive                     Segment  \
# 0          Greiff, Gene                   Annuities
# 1      Kellerman, Henry            Asset Management
# 2       Mitchell, Linda            Asset Management
# 3          Bing, Jeremy  Advice & Wealth Management
# 5      Vincent, Jeanine                   Annuities
# ..                  ...                         ...
# 630       Waterman, Lee                   Wholesale
# 631         Rink, Jenna                   Wholesale
# 632                 NaN                   Wholesale
# 633      Street, Stella                   Wholesale
# 634       Phillips, Doc                   Wholesale
#
#                    Project Type     Status Funding Status Total Actual Cost
# 0                  Breakthrough       Open       Finished            75,497
# 1                          Core       Open         Funded                 0
# 2                          Core       Open       Proposed                 0
# 3                          Core       Open         Funded                 0
# 5                          Core       Open         Funded                 0
# ..                          ...        ...            ...               ...
# 630          Strategic Priority  Candidate         Demand               NaN
# 631               Discretionary  Candidate         Demand               NaN
# 632                Breakthrough       Open       Canceled                 0
# 633  Improvement/Line Extension  Candidate         Demand                 0
# 634                Breakthrough  Candidate         Demand               NaN
#
# [630 rows x 14 columns]

# %% [markdown]
# ### Merge the two data frames to create the portfolio of projects

# %%
# Merge the two DataFrames using a left join
portfolio_df = pd.merge(projects_df, strategy_df, on="Project ID", how="left")
portfolio_df
# Out:
#        Project ID                           Project Name Start Date  \
# 0    AB-U38510550  Upgrd - Facilities Maintenance System   6/7/2019
# 1    AC-D39121594                DB2 to Oracle Migration   2/8/2018
# 2    AC-G38719560                   General Ledger (ERP)   1/2/2020
# 3    AC-M39177596             Marketing Data Integration   4/5/2018
# 4    AC-R38763567                    Requirements System  2/15/2020
# ..            ...                                    ...        ...
# 625  WS-S40909321              Single Sign On and Portal   1/1/2020
# 626  WS-S40909791                  Sales Training Design   1/1/2020
# 627  WS-T39914244                        Treasury Portal  4/11/2020
# 628  WS-W40909395           Workflow Enablement - Wave 3   1/1/2020
# 629  WS-W40909396           Workflow Enablement - Wave 2   1/1/2020
#
#        End Date                                        Description  \
# 0      5/1/2020  Managing assets is a critical component to the...
# 1    11/10/2018                                                NaN
# 2     4/20/2020  The General Ledger (ERP) project supports the ...
# 3     2/23/2019                                                NaN
# 4     3/23/2020                                                NaN
# ..          ...                                                ...
# 625  12/31/2020  This project is intended to provide a single s...
# 626    1/1/2020  Implement RM on-boarding and training program ...
# 627  11/15/2020  Treasury clients today use a variety of produc...
# 628    1/1/2020           Extend workflow capabilities to all LOBs
# 629    1/1/2020  Enhance workflow to accommodate deal routing b...
#
#     Number of Dependents Total Funded Budget Total Planned Cost  \
# 0                      4              75,497            163,000
# 1                    NaN             310,000            310,000
# 2                      0                   0            550,000
# 3                    NaN             150,000            150,000
# 4                    NaN             186,000            186,000
# ..                   ...                 ...                ...
# 625                    2                 NaN            115,500
# 626                    0                 NaN            142,300
# 627                    4                   0            156,000
# 628                    3                 NaN            101,000
# 629                    2                 NaN            155,700
#
#     Portfolio Executive                     Segment  \
# 0          Greiff, Gene                   Annuities
# 1      Kellerman, Henry            Asset Management
# 2       Mitchell, Linda            Asset Management
# 3          Bing, Jeremy  Advice & Wealth Management
# 4      Vincent, Jeanine                   Annuities
# ..                  ...                         ...
# 625       Waterman, Lee                   Wholesale
# 626         Rink, Jenna                   Wholesale
# 627                 NaN                   Wholesale
# 628      Street, Stella                   Wholesale
# 629       Phillips, Doc                   Wholesale
#
#                    Project Type     Status Funding Status Total Actual Cost  \
# 0                  Breakthrough       Open       Finished            75,497
# 1                          Core       Open         Funded                 0
# 2                          Core       Open       Proposed                 0
# 3                          Core       Open         Funded                 0
# 4                          Core       Open         Funded                 0
# ..                          ...        ...            ...               ...
# 625          Strategic Priority  Candidate         Demand               NaN
# 626               Discretionary  Candidate         Demand               NaN
# 627                Breakthrough       Open       Canceled                 0
# 628  Improvement/Line Extension  Candidate         Demand                 0
# 629                Breakthrough  Candidate         Demand               NaN
#
#      Strategy Score                 Primary Support Strategy  Risk Score
# 0              59.0  Support for Competitive Differentiation        73.0
# 1              36.0           Support for External Customers        33.0
# 2              36.0       Support for Increased Productivity        77.0
# 3              50.0           Support for External Customers        40.0
# 4              89.0           Support for External Customers        70.0
# ..              ...                                      ...         ...
# 625            75.0       Support for Increased Productivity        43.0
# 626            52.0       Support for Increased Productivity        43.0
# 627            66.0           Support for External Customers        70.0
# 628            37.0               Support for Reducing Costs        57.0
# 629            57.0               Support for Reducing Costs        30.0
#
# [630 rows x 17 columns]

# %%
# Output data frame to csv
portfolio_df.to_csv("Output/project_portfolio.csv",index=False)

# %% [markdown]
# ### Project Type

# %%
# Overview of Project Type
portfolio_df["Project Type"].value_counts()
# Out:
# Discretionary                 87
# New Product                   86
# Strategic Priority            83
# Regulatory                    81
# Maintenance-Other             62
# Core                          48
# Improvement/Line Extension    43
# Breakthrough                  41
# Customization                 41
# Productivity                  25
# Not Aligned                   15
# Maintenance                   10
# Strategic Initiative           1
# Name: Project Type, dtype: int64

# %% [markdown]
# ### Primary Support Strategy

# %%
# Overview of Primary Support Strategy
portfolio_df["Primary Support Strategy"].value_counts()
# Out:
# Support for Reducing Costs                 166
# Support for External Customers             158
# Support for Competitive Differentiation    102
# Support for Increased Productivity          93
# Support for Internal Customers              80
# Name: Primary Support Strategy, dtype: int64

# %% [markdown]
# ### Segment

# %%
# Overview of Segment
portfolio_df["Segment"].value_counts()
# Out:
# Consumer                      232
# Wholesale                     157
# Technology and Operations      57
# Corporate Functions            53
# Risk                           48
# Mortgage                       23
# Business Intelligence          18
# Advice & Wealth Management     11
# Asset Management                9
# Protection                      8
# Annuities                       5
# Corporate & Other               5
# Not Aligned                     3
# Name: Segment, dtype: int64

# %% [markdown]
# ### Funding Status

# %%
# Overview of Funding Status
portfolio_df["Funding Status"].value_counts()
# Out:
# Approved                         170
# Demand                           168
# Concluded (FOR EPMO USE ONLY)     84
# Active                            75
# Canceled                          37
# New                               32
# Funded                            30
# On Hold                           14
# Completed                          7
# Withdrawn (FOR EPMO USE ONLY)      6
# Proposed                           6
# Finished                           1
# Name: Funding Status, dtype: int64

# %% [markdown]
# ## Load the data
#
# * Load the portfolio data into PostgreSQL database

# %% [markdown]
# ### Create database connection to accolade_db

# %%
# Please verify that db_connection string that is located in config.py is correct before running this cell
engine = create_engine(db_connection)

# %%
# Confirm tables
engine.table_names()
# Out:
# ['project_portfolio']

# %%
# Load data frame into database
portfolio_df.to_sql(name='project_portfolio', con=engine, if_exists='replace')

# %%
# Query database to find states with negative energy difference values
strategy_over90 = engine.execute('select "Project ID" from project_portfolio where "Strategy Score" > 90').fetchall()
strategy_over90 = [project_id[0] for project_id in strategy_over90]

# Output query results
print('The following Projects have the highest strategy scores in the portfolio:')
for project_id in strategy_over90:
    print(project_id)
# Out:
# The following Projects have the highest strategy scores in the portfolio:
# CM-E40910804
# CS-C40358641
# CS-C40603685
# CS-F40581683
# CS-I40755707
# CS-I40802301
# CS-O40909775
# CS-O40909785
# CS-P40909772
# CS-R4054421
# CS-S40483656
# MM-R4090968
# M-P40940144
# RR-F40911136
# TR-I41183492
# WM-S4090986
# WM-D41001169
# WM-U42019549
# WP-R40770714
# WS-E40617695
